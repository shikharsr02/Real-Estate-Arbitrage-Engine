# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv(r'C:\Users\sahil\OneDrive\Desktop\Own Projects\Residential\Real_Estate_Cleaned_3.csv')

# %%
# Step 1 : Connecting to MySQL Database
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Shikher@07", 
    database="Residential" 
)

# %%
import pandas as pd

query="""
SELECT *
FROM staging_real_estate;
"""

df=pd.read_sql(query,conn)

df.head()
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_27564\1179938632.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,conn)
#                                                 Name     Price     Rate  \
# 0     4 BHK Flat for Sale in Vasant Vihar, New Delhi  85000000  21250.0
# 1  4 BHK Flat for Sale in Sushant Lok-I, Sector 4...  26500000   9815.0
# 2   3 BHK Flat for Sale in DLF City Phase 2, Gurgaon  29500000  15245.0
# 3  3 BHK Flat for Sale in Rohini Sector 24, New D...  12100000  10083.0
# 4  3 BHK Flat for Sale in Rohini Sector 8, New Delhi  25000000  31250.0
#
#                property         status            floor   transaction  \
# 0         Parnami Infra  Ready to Move       2 out of 4        Resale
# 1  Dolphin Real Estates  Ready to Move  Ground out of 4  New Property
# 2     The Unique Realty  Ready to Move       1 out of 4  New Property
# 3         Iconic Realty  Ready to Move       1 out of 4  New Property
# 4  Synergy Real Estates  Ready to Move       2 out of 4  New Property
#
#          facing             overlooking  ownership  ...  Rate_per_sqft  \
# 0  North - East             Garden/Park   Freehold  ...        21250.0
# 1  North - West               Main Road   Freehold  ...         9815.0
# 2         North  Garden/Park, Main Road   Freehold  ...        15245.0
# 3  North - East             Garden/Park   Freehold  ...        10083.0
# 4          East             Garden/Park  Leasehold  ...        31250.0
#
#    bedroom  carpet_area_sqft total_area Area_Unit    Area  Property_Type  \
# 0        4            3000.0    4000.00      sqft  3000.0           Flat
# 1        4            1500.0    2699.95      sqft  1500.0           Flat
# 2        3             144.0    1935.06     sqyrd   144.0           Flat
# 3        3            1100.0    1200.04      sqft  1100.0           Flat
# 4        3             750.0     800.00      sqft   750.0           Flat
#
#    carpet_area(in sqft)   Z_Score total_area(sqft)
# 0                3000.0  0.315354          4000.00
# 1                1500.0 -0.130664          2699.95
# 2                1296.0  0.577164          1935.06
# 3                1100.0 -0.121481          1200.04
# 4                 750.0  0.706537           800.00
#
# [5 rows x 25 columns]
